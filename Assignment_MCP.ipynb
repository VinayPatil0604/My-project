# %% [markdown]
# # Assignment

# %% [markdown]
# ## Q 1.

# %%
import pandas as pd

# %%
df=pd.read_csv("College.csv")

# %%
C1=pd.read_csv("College.csv",index_col=0)

# %%
C2=df.rename({"Unnamed: 0":"College"},axis=1)

# %%
C2=C2.set_index("College")

# %% [markdown]
# ## Q 2.

# %%
df.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
df=pd.read_csv("College.csv")

# %%
 pip install --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas.plotting
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pandas.plotting (from versions: none)
# ERROR: No matching distribution found for pandas.plotting

# %%
from pandas.plotting import scatter_matrix
sel_col=["Top10perc","Apps","Enroll"]
scatter_matrix(df[sel_col],figsize=(8,8),diagonal="hist")
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %%
Column="Apps"

# %%
import matplotlib.pyplot as plt

# %%
df.boxplot("Outstate",by="Private",figsize=(8,6))
        
plt.xlable("private(yes/no)")
plt.ylable("outstage")
plt.title("side by by boxbplot of outstate v/s private")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 3
#       1 df.boxplot("Outstate",by="Private",figsize=(8,6))
# ----> 3 plt.xlable("private(yes/no)")
#       4 plt.ylable("outstage")
#       5 plt.title("side by by boxbplot of outstate v/s private")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %%
df["Elite"]=pd.cut(df['Top10perc'],[0,0.5,1],["No","Yes"])
df["Elite"]

# %%
df["Elite"].value_counts()

# %%
df.boxplot("Outstate",by="Elite",figsize=(4,4))
        
plt.xlable("private(yes/no)")
plt.ylable("outstage")
plt.title("side by by boxbplot of outstate v/s private")
plt.show()

# %%
df=pd.read_csv("College.csv")

# %%
import numpy as np

# %%
#g)
plt.hist(df["Outstate"],bins=20,edgecolor="black")
#plt.subplot(2,1,2)
plt.show()

# %%
df.info
df.corr

# %% [markdown]
# # 9.

# %% [markdown]
# # Auto Dataset

# %%
DF_A=pd.read_csv("Auto.csv")
DF_A

# %%
DF_A.info()
DF_A.corr()

# %%
b=DF_A.min()
b

# %%
a=DF_A.max()
a

# %%
DF_A.mean

# %%
DF_A.std

# %%
DF_A1=DF_A.drop(DF_A.index[10:86])
DF_A1

# %%
DF_A.describe()

# %% [markdown]
# # e)

# %%
plt.figure(figsize=(5,4))
plt.scatter(DF_A["mpg"],DF_A["weight"],alpha=0.7,c="green")
plt.title("scatter plot mpg v/s year")
plt.show()

# %%
plt.figure(figsize=(5,4))
plt.hist(DF_A["mpg"],bins=20,color="white",edgecolor="black")
plt.title("histogram of mpg")

# %% [markdown]
# # 10. Boston Housing data

# %%
pip install pandoc

# %% [markdown]
# # a)

# %%
bh=pd.read_excel("D:\ST-425\MCP\Boston_data.xlsx")
bh
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\VINAY\AppData\Local\Temp\ipykernel_14424\294949617.py:1: SyntaxWarning: invalid escape sequence '\S'
#   bh=pd.read_excel("D:\ST-425\MCP\Boston_data.xlsx")
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# ...

# %% [markdown]
# # b)

# %%
print("No. of colums:",bh.shape[0])
print("No. of Rows:",bh.shape[0])
# Out:
# No. of colums: 506
# No. of Rows: 506

# %%
bh.info
# Out:
# <bound method DataFrame.info of         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# ...

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as se

# %%
bh_predictor=bh.drop(columns=["medv"],errors="ignore")

# %%
se.pairplot(bh_predictor)
plt.show()
